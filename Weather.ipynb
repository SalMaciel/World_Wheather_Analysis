# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | quelimane
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | ojinaga
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | veraval
# Processing Record 15 of Set 1 | sabang
# Processing Record 16 of Set 1 | fort abbas
# Processing Record 17 of Set 1 | baykit
# Processing Record 18 of Set 1 | bahia blanca
# Processing Record 19 of Set 1 | srednekolymsk
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | chik
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | puerto lempira
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | hirara
# Processing Record 28 of Set 1 | broome
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | salalah
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | constitucion
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | kukshi
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | grosseto
# Processing Record 46 of Set 1 | abu kamal
# Processing Record 47 of Set 1 | sitka
# Processing Record 48 of Set 1 | taltal
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | saint-denis
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | olmos
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | orthez
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | viransehir
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | san juan del rio
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | oktyabrskiy
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | blackwater
# Processing Record 19 of Set 2 | rocha
# Processing Record 20 of Set 2 | neuquen
# Processing Record 21 of Set 2 | portland
# Processing Record 22 of Set 2 | ketchikan
# Processing Record 23 of Set 2 | tautira
# Processing Record 24 of Set 2 | trogir
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | egvekinot
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | tamandare
# Processing Record 30 of Set 2 | labuhan
# Processing Record 31 of Set 2 | benguela
# Processing Record 32 of Set 2 | grand gaube
# Processing Record 33 of Set 2 | lamu
# Processing Record 34 of Set 2 | mpanda
# Processing Record 35 of Set 2 | sisimiut
# Processing Record 36 of Set 2 | lethem
# Processing Record 37 of Set 2 | urumqi
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | tobermory
# Processing Record 40 of Set 2 | grand forks
# Processing Record 41 of Set 2 | yar-sale
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | boueni
# Processing Record 45 of Set 2 | nioki
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | alyangula
# Processing Record 48 of Set 2 | san luis
# Processing Record 49 of Set 2 | hima
# Processing Record 50 of Set 2 | celano
# Processing Record 1 of Set 3 | mayya
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | conceicao do araguaia
# Processing Record 5 of Set 3 | mount isa
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | carballo
# Processing Record 11 of Set 3 | muscat
# Processing Record 12 of Set 3 | manokwari
# Processing Record 13 of Set 3 | vila do maio
# Processing Record 14 of Set 3 | waipawa
# Processing Record 15 of Set 3 | bom jesus
# Processing Record 16 of Set 3 | la ronge
# Processing Record 17 of Set 3 | lagoa
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | xiuyan
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | adrar
# Processing Record 23 of Set 3 | veinticinco de mayo
# Processing Record 24 of Set 3 | kyra
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | college
# Processing Record 28 of Set 3 | leshukonskoye
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | omboue
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | coffs harbour
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | hakodate
# Processing Record 42 of Set 3 | tomatlan
# Processing Record 43 of Set 3 | saint anthony
# Processing Record 44 of Set 3 | gigmoto
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | takoradi
# Processing Record 49 of Set 3 | victoria point
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 4 | praia
# Processing Record 4 of Set 4 | sorong
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | lata
# Processing Record 7 of Set 4 | keuruu
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | aguimes
# Processing Record 10 of Set 4 | san quintin
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | meulaboh
# Processing Record 13 of Set 4 | charleston
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | camacha
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | sivas
# Processing Record 18 of Set 4 | bairiki
# Processing Record 19 of Set 4 | malinovoye ozero
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | naze
# Processing Record 23 of Set 4 | sorland
# Processing Record 24 of Set 4 | chillicothe
# Processing Record 25 of Set 4 | betsiamites
# Processing Record 26 of Set 4 | mana
# Processing Record 27 of Set 4 | ambunti
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | carligele
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | tawang
# Processing Record 33 of Set 4 | borogontsy
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | tagusao
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | kapaa
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | margate
# Processing Record 41 of Set 4 | innisfail
# Processing Record 42 of Set 4 | lyngdal
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | paso de los toros
# Processing Record 45 of Set 4 | chingirlau
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | kudahuvadhoo
# Processing Record 48 of Set 4 | mataiea
# City not found. Skipping...
# Processing Record 49 of Set 4 | muzhi
# Processing Record 50 of Set 4 | yinchuan
# Processing Record 1 of Set 5 | athabasca
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | abu dhabi
# Processing Record 5 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | buenaventura
# Processing Record 8 of Set 5 | kaitangata
# Processing Record 9 of Set 5 | mahebourg
# Processing Record 10 of Set 5 | phatthalung
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | caravelas
# Processing Record 14 of Set 5 | comodoro rivadavia
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | cap malheureux
# Processing Record 17 of Set 5 | teacapan
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | kushima
# Processing Record 20 of Set 5 | aklavik
# Processing Record 21 of Set 5 | pangnirtung
# Processing Record 22 of Set 5 | severo-kurilsk
# Processing Record 23 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | rzhyshchiv
# Processing Record 26 of Set 5 | mugumu
# Processing Record 27 of Set 5 | kruisfontein
# Processing Record 28 of Set 5 | elko
# Processing Record 29 of Set 5 | granja
# Processing Record 30 of Set 5 | biak
# Processing Record 31 of Set 5 | sheregesh
# Processing Record 32 of Set 5 | batticaloa
# Processing Record 33 of Set 5 | sao miguel
# Processing Record 34 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 5 | sechura
# Processing Record 36 of Set 5 | arrecife
# Processing Record 37 of Set 5 | cidreira
# Processing Record 38 of Set 5 | seoul
# Processing Record 39 of Set 5 | wuwei
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | taoudenni
# Processing Record 42 of Set 5 | vostok
# Processing Record 43 of Set 5 | dikson
# Processing Record 44 of Set 5 | marakkanam
# Processing Record 45 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | rodeo
# Processing Record 48 of Set 5 | sibay
# Processing Record 49 of Set 5 | novo horizonte
# Processing Record 50 of Set 5 | turukhansk
# Processing Record 1 of Set 6 | atbasar
# Processing Record 2 of Set 6 | howard springs
# Processing Record 3 of Set 6 | benjamin hill
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | zhigansk
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | mirnyy
# Processing Record 8 of Set 6 | bandundu
# Processing Record 9 of Set 6 | sao miguel do araguaia
# Processing Record 10 of Set 6 | sanchez
# Processing Record 11 of Set 6 | nortelandia
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | kazachinskoye
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | sur
# Processing Record 16 of Set 6 | sembakung
# Processing Record 17 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 6 | upernavik
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | saint-louis
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | young
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | bubaque
# Processing Record 25 of Set 6 | bundaberg
# Processing Record 26 of Set 6 | neyshabur
# Processing Record 27 of Set 6 | sorokino
# Processing Record 28 of Set 6 | tasiilaq
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | hof
# Processing Record 31 of Set 6 | samarai
# Processing Record 32 of Set 6 | nola
# Processing Record 33 of Set 6 | shelburne
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | panzhihua
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | lesnyye polyany
# Processing Record 39 of Set 6 | yarkovo
# Processing Record 40 of Set 6 | longyearbyen
# Processing Record 41 of Set 6 | eydhafushi
# Processing Record 42 of Set 6 | acajutla
# Processing Record 43 of Set 6 | katherine
# Processing Record 44 of Set 6 | kaeo
# Processing Record 45 of Set 6 | villarrica
# Processing Record 46 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 6 | morki
# Processing Record 48 of Set 6 | tsabong
# Processing Record 49 of Set 6 | onguday
# Processing Record 50 of Set 6 | sobolevo
# Processing Record 1 of Set 7 | bambous virieux
# Processing Record 2 of Set 7 | caxito
# Processing Record 3 of Set 7 | fallon
# Processing Record 4 of Set 7 | kabo
# Processing Record 5 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 7 | kantunilkin
# Processing Record 7 of Set 7 | bandipur
# Processing Record 8 of Set 7 | shimoda
# Processing Record 9 of Set 7 | praia da vitoria
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | soller
# Processing Record 12 of Set 7 | grande-riviere
# City not found. Skipping...
# Processing Record 13 of Set 7 | alice springs
# Processing Record 14 of Set 7 | liverpool
# Processing Record 15 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 7 | korem
# Processing Record 17 of Set 7 | bollnas
# Processing Record 18 of Set 7 | diapaga
# Processing Record 19 of Set 7 | hobyo
# Processing Record 20 of Set 7 | staryy nadym
# Processing Record 21 of Set 7 | boone
# Processing Record 22 of Set 7 | aden
# Processing Record 23 of Set 7 | grand-santi
# Processing Record 24 of Set 7 | irbeyskoye
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | kaka
# Processing Record 28 of Set 7 | jutai
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | meadville
# Processing Record 31 of Set 7 | durban
# Processing Record 32 of Set 7 | kieta
# Processing Record 33 of Set 7 | hay river
# Processing Record 34 of Set 7 | fria
# Processing Record 35 of Set 7 | santiago de cao
# Processing Record 36 of Set 7 | kasongo-lunda
# Processing Record 37 of Set 7 | moindou
# Processing Record 38 of Set 7 | yandoon
# City not found. Skipping...
# Processing Record 39 of Set 7 | gotsu
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | nyurba
# Processing Record 42 of Set 7 | berlevag
# Processing Record 43 of Set 7 | agirish
# Processing Record 44 of Set 7 | steamboat springs
# Processing Record 45 of Set 7 | omsukchan
# Processing Record 46 of Set 7 | ilulissat
# Processing Record 47 of Set 7 | owando
# Processing Record 48 of Set 7 | airai
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | raichur
# Processing Record 1 of Set 8 | chifeng
# Processing Record 2 of Set 8 | skibbereen
# Processing Record 3 of Set 8 | umaria
# Processing Record 4 of Set 8 | sao francisco do sul
# Processing Record 5 of Set 8 | tiksi
# Processing Record 6 of Set 8 | kangaatsiaq
# Processing Record 7 of Set 8 | tucurui
# Processing Record 8 of Set 8 | rio grande
# Processing Record 9 of Set 8 | namie
# Processing Record 10 of Set 8 | havelock
# Processing Record 11 of Set 8 | havoysund
# Processing Record 12 of Set 8 | noumea
# Processing Record 13 of Set 8 | rudbar
# Processing Record 14 of Set 8 | zambezi
# Processing Record 15 of Set 8 | marihatag
# Processing Record 16 of Set 8 | walvis bay
# Processing Record 17 of Set 8 | sogne
# Processing Record 18 of Set 8 | tarecuato
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | chokurdakh
# Processing Record 21 of Set 8 | bingol
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | boysun
# Processing Record 24 of Set 8 | nabire
# Processing Record 25 of Set 8 | panguna
# Processing Record 26 of Set 8 | marsa matruh
# Processing Record 27 of Set 8 | new philadelphia
# Processing Record 28 of Set 8 | abu samrah
# Processing Record 29 of Set 8 | tynda
# Processing Record 30 of Set 8 | rio negrinho
# Processing Record 31 of Set 8 | newton
# Processing Record 32 of Set 8 | kolokani
# Processing Record 33 of Set 8 | charters towers
# Processing Record 34 of Set 8 | vrede
# Processing Record 35 of Set 8 | mandurah
# Processing Record 36 of Set 8 | mehamn
# Processing Record 37 of Set 8 | north bend
# Processing Record 38 of Set 8 | trang
# Processing Record 39 of Set 8 | black river
# Processing Record 40 of Set 8 | voitsberg
# Processing Record 41 of Set 8 | umm kaddadah
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | muskogee
# Processing Record 44 of Set 8 | shaowu
# Processing Record 45 of Set 8 | esperance
# Processing Record 46 of Set 8 | murray bridge
# Processing Record 47 of Set 8 | bengkulu
# Processing Record 48 of Set 8 | kampong chhnang
# Processing Record 49 of Set 8 | pacifica
# Processing Record 50 of Set 8 | oranjemund
# Processing Record 1 of Set 9 | sulphur springs
# Processing Record 2 of Set 9 | tiarei
# Processing Record 3 of Set 9 | moron
# Processing Record 4 of Set 9 | am timan
# Processing Record 5 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 9 | meadow lake
# Processing Record 7 of Set 9 | siirt
# Processing Record 8 of Set 9 | batie
# Processing Record 9 of Set 9 | svetlogorsk
# Processing Record 10 of Set 9 | xai-xai
# Processing Record 11 of Set 9 | karasjok
# Processing Record 12 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 9 | sao filipe
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | dwarka
# Processing Record 16 of Set 9 | tuy hoa
# Processing Record 17 of Set 9 | kumylzhenskaya
# Processing Record 18 of Set 9 | saint-augustin
# Processing Record 19 of Set 9 | nishihara
# Processing Record 20 of Set 9 | paragominas
# Processing Record 21 of Set 9 | suez
# Processing Record 22 of Set 9 | demba
# Processing Record 23 of Set 9 | piritiba
# Processing Record 24 of Set 9 | abonnema
# Processing Record 25 of Set 9 | ahuimanu
# Processing Record 26 of Set 9 | san jeronimo
# Processing Record 27 of Set 9 | viedma
# Processing Record 28 of Set 9 | palomares
# Processing Record 29 of Set 9 | aitape
# Processing Record 30 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 9 | lufilufi
# Processing Record 32 of Set 9 | port lincoln
# Processing Record 33 of Set 9 | richards bay
# Processing Record 34 of Set 9 | esso
# Processing Record 35 of Set 9 | inhambane
# Processing Record 36 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 9 | inirida
# Processing Record 38 of Set 9 | solnechnyy
# Processing Record 39 of Set 9 | clonakilty
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | seguela
# Processing Record 42 of Set 9 | gorontalo
# Processing Record 43 of Set 9 | kismayo
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | olafsvik
# Processing Record 46 of Set 9 | massaguet
# Processing Record 47 of Set 9 | poya
# Processing Record 48 of Set 9 | kharian
# Processing Record 49 of Set 9 | victor harbor
# Processing Record 50 of Set 9 | puerto madryn
# Processing Record 1 of Set 10 | carutapera
# Processing Record 2 of Set 10 | solano
# Processing Record 3 of Set 10 | leningradskiy
# Processing Record 4 of Set 10 | sucua
# Processing Record 5 of Set 10 | igrim
# Processing Record 6 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 10 | husavik
# Processing Record 8 of Set 10 | manono
# Processing Record 9 of Set 10 | nenjiang
# Processing Record 10 of Set 10 | port keats
# Processing Record 11 of Set 10 | hualmay
# Processing Record 12 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | altamira
# Processing Record 15 of Set 10 | khon kaen
# Processing Record 16 of Set 10 | linqiong
# Processing Record 17 of Set 10 | ganzhou
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | lempaala
# Processing Record 20 of Set 10 | brae
# Processing Record 21 of Set 10 | leh
# Processing Record 22 of Set 10 | cascais
# Processing Record 23 of Set 10 | larreynaga
# Processing Record 24 of Set 10 | dunedin
# Processing Record 25 of Set 10 | lasa
# Processing Record 26 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 10 | gasa
# Processing Record 28 of Set 10 | shar
# Processing Record 29 of Set 10 | trairi
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | state college
# Processing Record 32 of Set 10 | marrakesh
# Processing Record 33 of Set 10 | ust-kulom
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | sarkikaraagac
# Processing Record 36 of Set 10 | aubenas
# Processing Record 37 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 39 of Set 10 | bhuj
# Processing Record 40 of Set 10 | sandnessjoen
# Processing Record 41 of Set 10 | sydney
# Processing Record 42 of Set 10 | bako
# Processing Record 43 of Set 10 | thanh hoa
# Processing Record 44 of Set 10 | weihe
# Processing Record 45 of Set 10 | nador
# Processing Record 46 of Set 10 | bolshaya sosnova
# Processing Record 47 of Set 10 | yumen
# Processing Record 48 of Set 10 | evanston
# Processing Record 49 of Set 10 | hofn
# Processing Record 50 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 11 | nehe
# Processing Record 2 of Set 11 | krasnoselkup
# Processing Record 3 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 4 of Set 11 | guiratinga
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | pastavy
# Processing Record 7 of Set 11 | lardos
# Processing Record 8 of Set 11 | ponce
# Processing Record 9 of Set 11 | tinskoy
# Processing Record 10 of Set 11 | alexander city
# Processing Record 11 of Set 11 | bukachacha
# Processing Record 12 of Set 11 | waingapu
# Processing Record 13 of Set 11 | joaima
# Processing Record 14 of Set 11 | benjamin aceval
# Processing Record 15 of Set 11 | dillon
# Processing Record 16 of Set 11 | tondano
# Processing Record 17 of Set 11 | chicama
# Processing Record 18 of Set 11 | amurzet
# Processing Record 19 of Set 11 | abeche
# Processing Record 20 of Set 11 | kokopo
# Processing Record 21 of Set 11 | adre
# Processing Record 22 of Set 11 | ishlei
# City not found. Skipping...
# Processing Record 23 of Set 11 | plouzane
# Processing Record 24 of Set 11 | ixtapa
# Processing Record 25 of Set 11 | portales
# Processing Record 26 of Set 11 | tingo maria
# Processing Record 27 of Set 11 | guelavia
# City not found. Skipping...
# Processing Record 28 of Set 11 | manaus
# Processing Record 29 of Set 11 | tashla
# Processing Record 30 of Set 11 | djibo
# Processing Record 31 of Set 11 | west wendover
# Processing Record 32 of Set 11 | nabha
# Processing Record 33 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 11 | rabo de peixe
# Processing Record 35 of Set 11 | itaqui
# Processing Record 36 of Set 11 | ondjiva
# Processing Record 37 of Set 11 | amapa
# Processing Record 38 of Set 11 | najran
# Processing Record 39 of Set 11 | inongo
# Processing Record 40 of Set 11 | ancud
# Processing Record 41 of Set 11 | nokaneng
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | salme
# Processing Record 44 of Set 11 | sajanan
# Processing Record 45 of Set 11 | xichang
# Processing Record 46 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 47 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 11 | vaitape
# Processing Record 49 of Set 11 | oyama
# Processing Record 50 of Set 11 | san angelo
# Processing Record 1 of Set 12 | port macquarie
# Processing Record 2 of Set 12 | jodhpur
# Processing Record 3 of Set 12 | san-pedro
# Processing Record 4 of Set 12 | araouane
# Processing Record 5 of Set 12 | udachnyy
# Processing Record 6 of Set 12 | zyukayka
# Processing Record 7 of Set 12 | visby
# Processing Record 8 of Set 12 | slave lake
# Processing Record 9 of Set 12 | guiglo
# Processing Record 10 of Set 12 | altay
# Processing Record 11 of Set 12 | multan
# Processing Record 12 of Set 12 | yeppoon
# Processing Record 13 of Set 12 | den helder
# Processing Record 14 of Set 12 | trincomalee
# Processing Record 15 of Set 12 | mafra
# Processing Record 16 of Set 12 | alta floresta
# Processing Record 17 of Set 12 | cururupu
# Processing Record 18 of Set 12 | sohag
# Processing Record 19 of Set 12 | nara
# Processing Record 20 of Set 12 | edson
# Processing Record 21 of Set 12 | caete
# Processing Record 22 of Set 12 | mandalgovi
# Processing Record 23 of Set 12 | hirosaki
# Processing Record 24 of Set 12 | lishui
# Processing Record 25 of Set 12 | suileng
# Processing Record 26 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 27 of Set 12 | uruzgan
# Processing Record 28 of Set 12 | jiuquan
# Processing Record 29 of Set 12 | tilichiki
# Processing Record 30 of Set 12 | kawalu
# Processing Record 31 of Set 12 | remontnoye
# Processing Record 32 of Set 12 | magadan
# Processing Record 33 of Set 12 | la grande
# Processing Record 34 of Set 12 | chandbali
# Processing Record 35 of Set 12 | salekhard
# Processing Record 36 of Set 12 | khani
# Processing Record 37 of Set 12 | maoming
# Processing Record 38 of Set 12 | tezu
# Processing Record 39 of Set 12 | nantucket
# Processing Record 40 of Set 12 | punakha
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | porto novo
# Processing Record 43 of Set 12 | sibolga
# Processing Record 44 of Set 12 | krasnyy chikoy
# Processing Record 45 of Set 12 | flin flon
# Processing Record 46 of Set 12 | nhulunbuy
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | san matias
# Processing Record 49 of Set 12 | meleuz
# Processing Record 50 of Set 12 | baijiantan
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | tabalosos
# Processing Record 3 of Set 13 | sao felix do xingu
# Processing Record 4 of Set 13 | ialibu
# Processing Record 5 of Set 13 | mitu
# Processing Record 6 of Set 13 | balkanabat
# Processing Record 7 of Set 13 | neepawa
# Processing Record 8 of Set 13 | luanda
# Processing Record 9 of Set 13 | maceio
# Processing Record 10 of Set 13 | bagli
# Processing Record 11 of Set 13 | tha bo
# Processing Record 12 of Set 13 | miranorte
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Quelimane -17.8786   36.8883     73.04        96          67        6.87
# 1        Vaini -21.2000 -175.2000     73.56       100          75        3.44
# 2       Kodiak  57.7900 -152.4072     31.51        93           0        5.75
# 3  Tuktoyaktuk  69.4541 -133.0374     -0.76       100          98        2.42
# 4    Busselton -33.6500  115.3333     56.23        83           0       13.15
# 5     Hermanus -34.4187   19.2345     70.81        70          41        2.98
# 6    Grindavik  63.8424  -22.4338     46.87        93         100        8.05
# 7      Ojinaga  29.5667 -104.4167     89.56        39           0        0.00
# 8    Ostrovnoy  68.0531   39.5131     27.45        88          67        6.51
# 9      Veraval  20.9000   70.3667     86.99        55          91       17.36
#
#   Country                 Date
# 0      MZ  2022-04-20 16:08:53
# 1      TO  2022-04-20 16:08:53
# 2      US  2022-04-20 16:08:54
# 3      CA  2022-04-20 16:08:55
# 4      AU  2022-04-20 16:04:08
# 5      ZA  2022-04-20 16:08:56
# 6      IS  2022-04-20 16:08:57
# 7      MX  2022-04-20 16:08:57
# 8      RU  2022-04-20 16:08:58
# 9      IN  2022-04-20 16:08:58

# %%
new_order=['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df=city_data_df[new_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Quelimane      MZ  2022-04-20 16:08:53 -17.8786   36.8883     73.04
# 1        Vaini      TO  2022-04-20 16:08:53 -21.2000 -175.2000     73.56
# 2       Kodiak      US  2022-04-20 16:08:54  57.7900 -152.4072     31.51
# 3  Tuktoyaktuk      CA  2022-04-20 16:08:55  69.4541 -133.0374     -0.76
# 4    Busselton      AU  2022-04-20 16:04:08 -33.6500  115.3333     56.23
#
#    Humidity  Cloudiness  Wind Speed
# 0        96          67        6.87
# 1       100          75        3.44
# 2        93           0        5.75
# 3       100          98        2.42
# 4        83           0       13.15

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(0,80))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
